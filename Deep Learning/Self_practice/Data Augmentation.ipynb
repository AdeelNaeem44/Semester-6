# %%
import tensorflow as tf 
from tensorflow import keras
from keras.preprocessing import image

# %%
from tensorflow.keras.preprocessing.image import load_img

img = load_img(r'C:\Users\Adeel\Desktop\Deep Learning\Deep_learning\cat\cat.1.jpg', target_size=(200, 200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_gen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2
)

# %%
from tensorflow.keras.preprocessing.image import  img_to_array
img_array = img_to_array(img)

print(img_array.shape)
# Out:
# (200, 200, 3)

# %%
image_batch=img_array.reshape(1,200,200,3)

# %%
i=0
for output in data_gen.flow(image_batch,batch_size=1,save_to_dir='Data_augmented'):
    i=i+1
    if i==10:
        break

# %%
image_batch
# Out:
# array([[[[ 40.,  45.,  41.],
#          [ 41.,  45.,  44.],
#          [ 42.,  46.,  45.],
#          ...,
#          [217., 213., 188.],
#          [212., 209., 177.],
#          [206., 203., 167.]],
#
#         [[ 41.,  46.,  42.],
#          [ 41.,  45.,  44.],
#          [ 41.,  45.,  44.],
#          ...,
#          [206., 202., 176.],
#          [204., 200., 170.],
#          [204., 199., 166.]],
#
#         [[ 40.,  45.,  41.],
#          [ 39.,  43.,  42.],
#          [ 38.,  42.,  41.],
#          ...,
#          [200., 195., 172.],
#          [202., 198., 168.],
#          [210., 205., 172.]],
#
#         ...,
#
#         [[ 29.,  27.,  28.],
#          [ 25.,  23.,  24.],
#          [ 22.,  20.,  21.],
#          ...,
#          [ 51.,  38.,  31.],
#          [ 42.,  28.,  22.],
#          [ 50.,  39.,  32.]],
#
#         [[ 32.,  30.,  31.],
#          [ 26.,  24.,  25.],
#          [ 23.,  21.,  22.],
#          ...,
#          [ 38.,  24.,  18.],
# ...

# %%
from tensorflow.keras.preprocessing.image import array_to_img


img_converted = array_to_img(img_array)

# %%
img_converted
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
